# %%
#!/usr/bin/python

import urllib2
import simplejson
import json
import pandas as pd
import re
import numpy as np
import ast
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.path.dirname("__file__"), '../modules')))
#from pandas.io.json import json_normalize
from advancedstatistics import loadpanel, data2statistics, read_measure, statistics_tojson, advpanel2dict
from tabulardata import loadcodes, load_api_data, countryset, json_dict, createframe, combinedata, data2panel,  moderncodes
from config import configuration, dataverse2indicators, load_dataverse, findpid, load_metadata, load_fullmetadata
from historical import load_historical, histo
from paneldata import panel2dict, paneldatafilter, panel2csv
from datasets import loaddataset, loaddataset_fromurl, loadgeocoder, treemap, selectint, buildgeocoder, load_geocodes, datasetfilter, content2dataframe, dataset_analyzer, dataset2panel

# %%
def advanced_statistics(handles, totalpanel, geolist):
    #handle = 'Panel[%27hdl%3A10622/4X6NCK%27%2C%20%27hdl%3A10622/I0YK5M%27%2C%20%27hdl%3A10622/ZWRBOY%27]'    
    #handle = handle.replace(" ", '')
    #print handle
    yearmin = '1990'
    yearmax = '2010'
    ctrlist = ''
    ctrlist = '250,276'
    config = configuration()
    
    if totalpanel:
        cleanedpanel = totalpanel
        names = geolist
    else:        
        jsonapi = config['apiroot'] + '/api/datasets?handle=' + str(handles)        
        names = moderncodes(config['modernnames'], config['apiroot'])    
    
        (panel, cleanedpanel, unames) = loadpanel(jsonapi, yearmin, yearmax, ctrlist)
        (header, data, countries, handles, vhandles) = advpanel2dict(cleanedpanel)   
    
    #result = panel2csv(header, data, thisyear, countries, handles, vhandles, ctrlimit, modern)
    maindataframe = data2statistics(handles, cleanedpanel)    
    showhtml = statistics_tojson(maindataframe, names, unames)
    return showhtml

# %%
def request_geocoder(config):
    # Geocoder
    #if config['remote']:
    #    (classification, dataset, title, units) = loaddataset_fromurl(config, config['geocoderhandle'])
    #else:
    #    dataset = loaddataset(handles)
    (classification, dataset, title, units) = content2dataframe(config, config['geocoderhandle'])

    (geocoder, geolist, oecd2webmapper) = buildgeocoder(dataset, config, '')
    (modern, historical) = loadgeocoder(config, dataset, 'geocoder')
    coderyears = []
    for i in range(1500, 2015):
        coderyears.append(i)
    return (geocoder, geolist, oecd2webmapper, modern, historical)

# %%
def request_datasets(config, switch, modern, historical, handles, geolist):
    (ispanel, dataframe) = ('', {})    

    for handle in handles:
        (class1, dataset, title, units) = content2dataframe(config, handle)

        if switch == 'modern':
            activeindex = modern.index
            coder = modern
            class1 = switch
        else:
            activeindex = historical.index
            coder = historical

        (moderndata, historicaldata) = loadgeocoder(config, dataset, '')
        if switch == 'modern':
            maindata = moderndata
        else:
            # Do conversion to webmapper system
            if not historicaldata:
                maindata = moderndata
                webmapperindex = []
                for code in maindata.index:
                    try:
                        webmappercode = oecd2webmapper[int(code)]
                    except:
                        webmappercode = -1
                    webmapperindex.append(webmappercode)
                maindata.index = webmapperindex
                maindata = maindata[maindata.index > 0]
            else:
                maindata = historicaldata
    
        (cfilter, notint) = selectint(maindata.columns)
    
        codes = selectint(maindata.index)
        geo = load_geocodes(config, switch, codes, maindata, geolist)
        for colname in notint:
            maindata = maindata.drop(colname, axis=1)       
        # Drop num if in dataframe
        if '1' in maindata.columns:
            maindata = maindata.drop('1', axis=1)
        dataframe[handle] = maindata
    
    return (dataset, dataframe)

# %%
# Use case 1
datafilter = {}
datafilter['startyear'] = '1950'
datafilter['endyear'] = '2010'
#datafilter['ctrlist'] = '528,14,18,67'
datafilter['ctrlist'] = '523'
datafilter['ctrlist'] = '1523'
datafilter['ctrlist'] = '250,276'
selectedyear = '0'
if int(selectedyear) > 0:
    datafilter['startyear'] = selectedyear
    datafilter['endyear'] = selectedyear    
    
datafilter['ctrlist'] = ''
if datafilter['startyear']:
    coderyears = []
    for i in range(int(datafilter['startyear']), int(datafilter['endyear'])):
        coderyears.append(i)
        
handles = ['hdl:10622/CSNW0F', 'hdl:10622/I0YK5M']
handles = ['hdl:10622/UFGBH1']
switch = 'modern'
#switch = 'historical'
config = configuration()
config['remote'] = 'yes'
(geocoder, geolist, oecd2webmapper, modern, historical) = request_geocoder(config)

# %%
(origdata, maindata) = request_datasets(config, switch, modern, historical, handles, geolist)
(subsets, panel) = ({}, [])
for handle in handles:
    #handle = 'hdl:10622/I0YK5M'    
    (datasubset, ctrlist) = datasetfilter(maindata[handle], datafilter)
    #datasubset['handle'] = handle
    if not datasubset.empty:
        datasubset = datasubset.dropna(how='all')
        panel.append(datasubset)
        subsets[handle] = datasubset    

#handle = 'hdl:10622/CSNW0F'
subsets[handles[0]]
#totalpanel = pd.concat(panel)
#totalpanel([1990, 2000])
# Out:
#          1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  ...   \
# Code                                                                 ...
# 40        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 56        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 280   176.800   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 250   173.175   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 276   176.800   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 528   178.700   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 208   179.800   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 233       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 246   178.000   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 372   174.900   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 578   178.100   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 752   179.300   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 826   176.000   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 70        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 191   175.100   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 300   173.700   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 380   171.300   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 620   167.410   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 688       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 891       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 705   175.800   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 724   170.800   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 112       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 100   172.900   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 203   177.700   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 200       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 348   175.400   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 616   173.200   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 498   172.007   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...       ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 562   170.946   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 566   168.544   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 686   173.913   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 694       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 768   170.800   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 120   171.251   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 140   169.300   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 148   173.690   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 178   168.447   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 180   168.469   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 266   171.200   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 72        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 426   167.970   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 516   171.906   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 710   170.100   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 748   169.473   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 174   166.800   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 262       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 232   156.700   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 230   166.823   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 231   166.823   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 404   169.884   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 450   164.056   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 454   166.617   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 508   165.967   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 646   168.887   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 800   169.822   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 834   166.195   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 894   169.635   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 716   170.988   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#       2001  2002  2003  2004  2005  2006  2007  2008  2009  2010
# Code
# 40     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 56     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 280    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 250    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 276    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 528    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 208    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 233    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 246    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 372    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 578    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 752    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 826    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 8      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 70     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 191    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 300    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 380    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 620    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 688    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 891    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 705    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 724    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 112    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 100    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 203    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 200    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 348    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 616    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 498    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 562    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 566    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 686    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 694    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 768    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 120    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 140    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 148    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 178    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 180    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 266    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 72     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 426    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 516    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 710    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 748    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 174    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 262    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 232    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 230    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 231    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 404    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 450    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 454    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 508    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 646    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 800    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 834    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 894    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 716    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [144 rows x 61 columns]

# %%
#handles = "Panel['hdl:10622/4X6NCK','hdl:10622/F16UDU','hdl:10622/I0YK5M']"
#totalpanel = []
#showhtml = advanced_statistics(handles, totalpanel, geolist)
#showhtml
            
logscale = '10'
(datapanel, original) = dataset2panel(config, subsets[handles[0]], modern, logscale)
datapanel
# Out:
# [['France', 1990, 4.764684131635809, 250],
#  ['Germany', 1990, 4.899713250172067, 276]]
