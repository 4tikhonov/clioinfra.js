# %%
#!/usr/bin/python

import urllib2
import simplejson
import json
import pandas as pd
import re
import numpy as np
import ast
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.path.dirname("__file__"), '../modules')))
#from pandas.io.json import json_normalize
from advancedstatistics import loadpanel, data2statistics, read_measure, statistics_tojson, advpanel2dict
from tabulardata import loadcodes, load_api_data, countryset, json_dict, createframe, combinedata, data2panel,  moderncodes
from config import configuration, dataverse2indicators, load_dataverse, findpid, load_metadata, load_fullmetadata
from historical import load_historical, histo
from paneldata import panel2dict, paneldatafilter, panel2csv
from datasets import loaddataset, loaddataset_fromurl, loadgeocoder, treemap, selectint, buildgeocoder, load_geocodes, datasetfilter, content2dataframe, dataset_analyzer

# %%
def advanced_statistics(handles, totalpanel, geolist):
    #handle = 'Panel[%27hdl%3A10622/4X6NCK%27%2C%20%27hdl%3A10622/I0YK5M%27%2C%20%27hdl%3A10622/ZWRBOY%27]'    
    #handle = handle.replace(" ", '')
    #print handle
    yearmin = '1990'
    yearmax = '2010'
    ctrlist = ''
    ctrlist = '250,276'
    config = configuration()
    
    if totalpanel:
        cleanedpanel = totalpanel
        names = geolist
    else:        
        jsonapi = config['apiroot'] + '/api/datasets?handle=' + str(handles)        
        names = moderncodes(config['modernnames'], config['apiroot'])    
    
        (panel, cleanedpanel, unames) = loadpanel(jsonapi, yearmin, yearmax, ctrlist)
        (header, data, countries, handles, vhandles) = advpanel2dict(cleanedpanel)   
    
    #result = panel2csv(header, data, thisyear, countries, handles, vhandles, ctrlimit, modern)
    maindataframe = data2statistics(handles, cleanedpanel)    
    showhtml = statistics_tojson(maindataframe, names, unames)
    return showhtml

# %%
def request_geocoder(config):
    # Geocoder
    #if config['remote']:
    #    (classification, dataset, title, units) = loaddataset_fromurl(config, config['geocoderhandle'])
    #else:
    #    dataset = loaddataset(handles)
    (classification, dataset, title, units) = content2dataframe(config, config['geocoderhandle'])

    (geocoder, geolist, oecd2webmapper) = buildgeocoder(dataset, config, '')
    (modern, historical) = loadgeocoder(config, dataset, 'geocoder')
    coderyears = []
    for i in range(1500, 2015):
        coderyears.append(i)
    return (geocoder, geolist, oecd2webmapper, modern, historical)

# %%
def request_datasets(config, switch, modern, historical, handles):
    (ispanel, dataframe) = ('', {})    

    for handle in handles:
        (class1, dataset, title, units) = content2dataframe(config, handle)

        if switch == 'modern':
            activeindex = modern.index
            coder = modern
            class1 = switch
        else:
            activeindex = historical.index
            coder = historical

        (moderndata, historicaldata) = loadgeocoder(config, dataset, '')
        if switch == 'modern':
            maindata = moderndata
        else:
            # Do conversion to webmapper system
            if not historicaldata:
                maindata = moderndata
                webmapperindex = []
                for code in maindata.index:
                    try:
                        webmappercode = oecd2webmapper[int(code)]
                    except:
                        webmappercode = -1
                    webmapperindex.append(webmappercode)
                maindata.index = webmapperindex
                maindata = maindata[maindata.index > 0]
            else:
                maindata = historicaldata
    
        (cfilter, notint) = selectint(maindata.columns)
    
        codes = selectint(maindata.index)
        geo = load_geocodes(config, switch, codes, maindata, geolist)
        for colname in notint:
            maindata = maindata.drop(colname, axis=1)       
        # Drop num if in dataframe
        if '1' in maindata.columns:
            maindata = maindata.drop('1', axis=1)
        dataframe[handle] = maindata
    
    return (dataset, dataframe)

# %%
# Use case 1
datafilter = {}
datafilter['startyear'] = '1950'
datafilter['endyear'] = '2010'
#datafilter['ctrlist'] = '528,14,18,67'
datafilter['ctrlist'] = '523'
datafilter['ctrlist'] = '1523'
datafilter['ctrlist'] = ''
if datafilter['startyear']:
    coderyears = []
    for i in range(int(datafilter['startyear']), int(datafilter['endyear'])):
        coderyears.append(i)
        
handles = ['hdl:10622/CSNW0F', 'hdl:10622/I0YK5M']
switch = 'modern'
switch = 'historical'
config = configuration()
config['remote'] = 'yes'
(geocoder, geolist, oecd2webmapper, modern, historical) = request_geocoder(config)

# %%
(origdata, maindata) = request_datasets(config, switch, modern, historical, handles)
(subsets, panel) = ({}, [])
for handle in handles:
    #handle = 'hdl:10622/I0YK5M'
    (datasubset, ctrlist) = datasetfilter(maindata[handle], datafilter)
    datasubset['handle'] = handle
    if not datasubset.empty:
        panel.append(datasubset)
    
    subsets[handle] = datasubset
handle = 'hdl:10622/I0YK5M'
#subsets[handle]
totalpanel = pd.concat(panel)
totalpanel
# Out:
#             1950        1960        1970        1980       1990       2000  \
# 1509   6935.1000   7047.4370   7467.0860   7549.4330   7722.953   8113.413
# 1519   8639.3690   9118.7000   9637.8000   9846.8000   9969.310  10263.618
# 1520  42518.0000  46584.0000  51918.0000  55110.0000  58168.000  61137.000
# 1594  68374.5720  72480.8690  77783.1640  78297.9040  79380.394  82187.909
# 1521     13.5000     16.4260     21.1030     25.0740     28.796     32.204
# 1522    295.5870    313.9690    339.1740    364.4000    382.966    438.777
# 1459     18.1250     20.7570     23.7520     26.5510     29.972     31.693
# 1523  10113.5270  11486.0000  13032.3350  14143.9010  14951.510  15907.853
# 1525   4694.0000   5362.0000   6267.0000   6385.2290   6836.626   7266.920
# 1511   4271.0000   4581.0000   4928.7570   5123.0270   5140.954   5337.416
# 1529   1095.6100   1210.6470   1363.1830   1482.1960   1569.322   1379.835
# 1530   4008.9000   4429.6000   4606.3070   4779.5350   4986.431   5168.595
# 1431    142.9380    175.8600    204.1040    228.1610    254.719    281.043
# 1432   2963.0180   2832.0000   2950.1000   3401.0000   3508.200   3791.690
# 1533   1936.4980   2115.1830   2361.1590   2524.5430   2663.590   2376.178
# 1538   2553.1590   2764.8640   3137.5620   3435.2890   3694.836   3654.387
# 1480   3265.1260   3581.2390   3877.3860   4085.6200   4242.006   4492.400
# 1482   7014.0050   7480.3950   8042.8030   8310.4730   8559.000   8872.000
# 1434  50127.0000  52372.0000  55632.0000  56314.0000  57493.307  59522.468
# 1495   1227.1560   1623.1140   2156.6120   2671.4120   3250.778   3473.835
# 1484      6.1760      8.3920     19.5450     33.5840     52.837     66.824
# 1496   2662.0000   3240.0000   3703.0000   4092.0000   4423.646   4035.457
# 1497   3837.2970   4036.1450   4205.3890   4383.0000   4508.347   4410.830
# 1503   7566.0280   8327.4050   8792.8060   9642.5050  10129.603  10559.110
# 1498  47105.0000  50197.6000  53661.1000  56451.2470  56742.886  57719.337
# 1442    311.9730    328.5170    325.5690    364.0010    359.107    389.947
# 1637    395.5870    461.4870    514.4720    560.0000    583.202    732.302
# 1456   8442.7500   9036.7000   9044.2000   9777.8000   9922.689  10335.597
# 1443     12.7800     15.4060     19.1890     21.4630     23.469     26.937
# 1638   6710.2610   7470.9360   8166.7260   8955.0000   9347.973  10117.908
# ...          ...         ...         ...         ...        ...        ...
# 1650         NaN         NaN         NaN         NaN        NaN        NaN
# 1492     41.3587     45.2180     42.5831         NaN        NaN        NaN
# 1527         NaN         NaN         NaN         NaN        NaN        NaN
# 1578         NaN         NaN         NaN         NaN        NaN        NaN
# 1640     52.9034     48.5776     47.8051     49.7924        NaN        NaN
# 1517         NaN         NaN         NaN         NaN        NaN        NaN
# 1577         NaN         NaN         NaN         NaN        NaN        NaN
# 1458     42.8936     42.4521     41.7387     42.2244        NaN        NaN
# 1463     41.9167         NaN         NaN         NaN        NaN        NaN
# 1591     48.9628     47.5437     46.1811     55.5145        NaN        NaN
# 1512         NaN         NaN         NaN         NaN        NaN        NaN
# 1472     49.9706     50.2608     50.7132         NaN        NaN        NaN
# 1534     41.6219     43.8829     42.4743         NaN        NaN        NaN
# 1497         NaN     39.3199         NaN         NaN        NaN        NaN
# 1407     34.4352     40.5536     35.0258     33.1921        NaN        NaN
# 1560         NaN         NaN         NaN         NaN        NaN        NaN
# 1600         NaN         NaN         NaN         NaN        NaN        NaN
# 1464     49.9683     52.1714     44.6549     43.2881        NaN        NaN
# 1519         NaN     41.2879         NaN         NaN        NaN        NaN
# 1523         NaN     54.3732         NaN         NaN        NaN        NaN
# 1440         NaN         NaN         NaN         NaN        NaN        NaN
# 1436     49.3005     48.8028     48.7430     43.7126        NaN        NaN
# 1446     48.8704     45.3474     46.8813     44.0757        NaN        NaN
# 1559     33.2527     34.8333     31.1235     35.2658        NaN        NaN
# 1448     42.6652     44.2301     44.5434         NaN        NaN        NaN
# 1486     56.4356     50.5720     58.0390         NaN        NaN        NaN
# 1516     46.1867     45.9973     46.2534     48.8291        NaN        NaN
# 1409     31.6350         NaN         NaN         NaN        NaN        NaN
# 1490     42.1469     45.1552     46.0216         NaN        NaN        NaN
# 1580     39.2117     43.8789     46.9896         NaN        NaN        NaN
#
#                 handle
# 1509  hdl:10622/CSNW0F
# 1519  hdl:10622/CSNW0F
# 1520  hdl:10622/CSNW0F
# 1594  hdl:10622/CSNW0F
# 1521  hdl:10622/CSNW0F
# 1522  hdl:10622/CSNW0F
# 1459  hdl:10622/CSNW0F
# 1523  hdl:10622/CSNW0F
# 1525  hdl:10622/CSNW0F
# 1511  hdl:10622/CSNW0F
# 1529  hdl:10622/CSNW0F
# 1530  hdl:10622/CSNW0F
# 1431  hdl:10622/CSNW0F
# 1432  hdl:10622/CSNW0F
# 1533  hdl:10622/CSNW0F
# 1538  hdl:10622/CSNW0F
# 1480  hdl:10622/CSNW0F
# 1482  hdl:10622/CSNW0F
# 1434  hdl:10622/CSNW0F
# 1495  hdl:10622/CSNW0F
# 1484  hdl:10622/CSNW0F
# 1496  hdl:10622/CSNW0F
# 1497  hdl:10622/CSNW0F
# 1503  hdl:10622/CSNW0F
# 1498  hdl:10622/CSNW0F
# 1442  hdl:10622/CSNW0F
# 1637  hdl:10622/CSNW0F
# 1456  hdl:10622/CSNW0F
# 1443  hdl:10622/CSNW0F
# 1638  hdl:10622/CSNW0F
# ...                ...
# 1650  hdl:10622/I0YK5M
# 1492  hdl:10622/I0YK5M
# 1527  hdl:10622/I0YK5M
# 1578  hdl:10622/I0YK5M
# 1640  hdl:10622/I0YK5M
# 1517  hdl:10622/I0YK5M
# 1577  hdl:10622/I0YK5M
# 1458  hdl:10622/I0YK5M
# 1463  hdl:10622/I0YK5M
# 1591  hdl:10622/I0YK5M
# 1512  hdl:10622/I0YK5M
# 1472  hdl:10622/I0YK5M
# 1534  hdl:10622/I0YK5M
# 1497  hdl:10622/I0YK5M
# 1407  hdl:10622/I0YK5M
# 1560  hdl:10622/I0YK5M
# 1600  hdl:10622/I0YK5M
# 1464  hdl:10622/I0YK5M
# 1519  hdl:10622/I0YK5M
# 1523  hdl:10622/I0YK5M
# 1440  hdl:10622/I0YK5M
# 1436  hdl:10622/I0YK5M
# 1446  hdl:10622/I0YK5M
# 1559  hdl:10622/I0YK5M
# 1448  hdl:10622/I0YK5M
# 1486  hdl:10622/I0YK5M
# 1516  hdl:10622/I0YK5M
# 1409  hdl:10622/I0YK5M
# 1490  hdl:10622/I0YK5M
# 1580  hdl:10622/I0YK5M
#
# [308 rows x 7 columns]

# %%
handles = "Panel['hdl:10622/4X6NCK','hdl:10622/F16UDU','hdl:10622/I0YK5M']"
totalpanel = []
showhtml = advanced_statistics(handles, totalpanel, geolist)
showhtml
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-9f69bb487ff1> in <module>()
#       1 handles = "Panel['hdl:10622/4X6NCK','hdl:10622/F16UDU','hdl:10622/I0YK5M']"
#       2 totalpanel = []
# ----> 3 showhtml = advanced_statistics(handles, totalpanel, geolist)
#       4 showhtml
#
# <ipython-input-2-644fee276be4> in advanced_statistics(handles, totalpanel, geolist)
#      21     #result = panel2csv(header, data, thisyear, countries, handles, vhandles, ctrlimit, modern)
#      22     maindataframe = data2statistics(handles, cleanedpanel)
# ---> 23     showhtml = statistics_tojson(maindataframe, names, unames)
#      24     return showhtml
#
# TypeError: statistics_tojson() takes exactly 2 arguments (3 given)
