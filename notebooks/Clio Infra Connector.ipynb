# %%
import urllib2 
import simplejson
import json
import pandas as pd
import re
import vincent
import numpy as np
from pandas.io.json import json_normalize

def load_api_data(apiurl, fileID):
    jsondataurl = apiurl
    
    req = urllib2.Request(jsondataurl)
    opener = urllib2.build_opener()
    f = opener.open(req)
    dataframe = simplejson.load(f, "utf-8")
    return dataframe

def loadnames(dataframe):
    header = dataframe[1]
    names = {}
    for name in header:
        try:
            names[name] = int(header[name])
        except:
            names[name] = header[name]
    return names

def transform(dataframe, names):
    transframe = {}
    for item in dataframe:
        for code in item:
            thisyear = names[code]
            value = item[code]            
            if not value:
                value = np.nan
            
            try:
                dataset = transframe[thisyear]
            except:
                dataset = []
                
            dataset.append(value)        
            transframe[thisyear] = dataset

    return transframe

jsonapi = "http://clearance.sandbox.socialhistoryservices.org/collabs/static/data/dataframe27_0.json"
dataframe = load_api_data(jsonapi, '')
names = loadnames(dataframe)
dataframe.pop(0)
dataframe.pop(0)
t = transform(dataframe, names)
#for x in t:
#    print str(x) + ' ' + str(t[x])

#print names
item = dataframe[2]
for x in item:
    year = names[x]
    value = item[x]
    #print str(year) + ' ' + str(value)

clioframe = pd.DataFrame(dataframe)
clioframe.head()
#years = pd.melt(clioframe, id_vars=['a'])
# Out:
#    Female Life Expectancy at birth Unnamed: 1 Unnamed: 10 Unnamed: 11  \
# 0                              752     Sweden       46.81       49.08
# 1                              250     France       38.34       43.68
# 2                              208    Denmark       46.95       45.72
# 3                              352    Iceland       42.51       44.73
# 4                               56    Belgium       41.73       43.96
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17  \
# 0       51.77       53.62       59.06       60.13       64.21       68.11
# 1       44.73       46.87       53.31       53.45       59.35       58.94
# 2       48.41       53.54       59.63       58.31       63.24       67.21
# 3        38.9       49.61        54.6       56.34       62.55       68.74
# 4       46.08       48.35       52.98       55.56       59.23       60.71
#
#       ...     Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 3 Unnamed: 4  \
# 0     ...           78.85       80.40       82.04      33.15      33.63
# 1     ...            78.4       80.97       82.80                 41.07
# 2     ...           77.18       77.73       79.12
# 3     ...           80.07       80.53       81.54
# 4     ...           76.66       79.34       80.90
#
#    Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0       41.84        43.4       46.1      47.26      50.26
# 1       39.94       40.33      41.14      43.97      43.84
# 2                   40.21      42.34      45.14      45.94
# 3                   34.23      32.61      38.29      21.46
# 4                              40.33       42.1       45.7
#
# [5 rows x 24 columns]

# %%
clioframemain = pd.DataFrame(t)
#x = clioframemain.loc
c = clioframemain
c = c.drop('Code', axis=1)
c = c.set_index('Continent, Region, Country')
#z.fillna(0)
z = c[1810]
z.describe()
#html = clioframemain.to_html()
# Out:
# count     2.000000
# mean     37.350000
# std       5.260874
# min      33.630000
# 25%      35.490000
# 50%      37.350000
# 75%      39.210000
# max      41.070000
# dtype: float64

# %%
slicedata = pd.DataFrame(clioframemain, columns = [1970, 'France'])
slicedata.sum()
# Out:
# 1970      11478.86
# France         NaN
# dtype: float64

# %%
df = clioframe.transpose()
yearsrow = df[df.columns[1]]
years = yearsrow[yearsrow[1] > 0]

# Remove none numberic values from years list
yearsrow.convert_objects(convert_numeric=True)
years = yearsrow.dropna() 
#years
df.head()
# Out:
#                                     0       1        2        3        4    \
# Female Life Expectancy at birth     752     250      208      352       56
# Unnamed: 1                       Sweden  France  Denmark  Iceland  Belgium
# Unnamed: 10                       46.81   38.34    46.95    42.51    41.73
# Unnamed: 11                       49.08   43.68    45.72    44.73    43.96
# Unnamed: 12                       51.77   44.73    48.41     38.9    46.08
#
#                                     5            6            7        8    \
# Female Life Expectancy at birth     578          528          756      246
# Unnamed: 1                       Norway  Netherlands  Switzerland  Finland
# Unnamed: 10                       52.55        38.35        41.81    40.08
# Unnamed: 11                       53.28        41.81        43.94    41.11
# Unnamed: 12                       53.03        45.71        46.32    46.11
#
#                                    9    ...                      190  \
# Female Life Expectancy at birth    380  ...                      659
# Unnamed: 1                       Italy  ...    Saint Kitts and Nevis
# Unnamed: 10                       30.2  ...
# Unnamed: 11                      33.14  ...
# Unnamed: 12                      38.57  ...
#
#                                       191               192         193  \
# Female Life Expectancy at birth       296               584         690
# Unnamed: 1                       Kiribati  Marshall Islands  Seychelles
# Unnamed: 10
# Unnamed: 11
# Unnamed: 12
#
#                                          194     195         196     197  \
# Female Life Expectancy at birth          833    9001         674     688
# Unnamed: 1                       Isle of Man  Kosovo  San Marino  Serbia
# Unnamed: 10
# Unnamed: 11
# Unnamed: 12
#
#                                    198                             199
# Female Life Expectancy at birth    585                             275
# Unnamed: 1                       Palau  Occupied Palestinian Territory
# Unnamed: 10
# Unnamed: 11
# Unnamed: 12
#
# [5 rows x 200 columns]

# %%
standards = df.drop(df.columns[[0]], axis=1)
countries = clioframe[clioframe.columns[1]]
codes = clioframe[clioframe.columns[0]]
c = pd.DataFrame({'codes': codes, 'countries': countries})
oecd = c[c['codes'] > 0]
oecd.head()
# Out:
#    codes countries
# 0    752    Sweden
# 1    250    France
# 2    208   Denmark
# 3    352   Iceland
# 4     56   Belgium

# %%
data = clioframe[clioframe.columns[2]]
data.describe()
# Out:
# count     200
# unique     11
# top
# freq      190
# dtype: object

# %%
def load_country(df, years, index):
    jsoncountries = df[df.columns[index]]
    countries = {}
    info = {}
    
    for key in jsoncountries.keys():
        value = jsoncountries[key]
        year = years[key]
        try: 
            digit = int(year)
            countries[year] = value
        except:
            info[year] = value
    
    return (countries, info)

yearsrow = df[df.columns[1]]
years = yearsrow[yearsrow[1] > 0]
(dataset, info) = load_country(df, names, 6)

clioframe = pd.DataFrame(dataset, index=[0])
clioframe.head()
#clioframe.sum()
# Out:
#   1750 1800 1810 1820 1830 1840   1850   1860   1870   1880  ...     1910  \
# 0                                40.81  37.98  38.35  41.81  ...    56.22
#
#     1920   1930   1940   1950   1960   1970   1980   1990   2000
# 0  58.76  65.41  67.29  72.59  75.31  76.52  79.14  80.08  80.57
#
# [1 rows x 22 columns]
