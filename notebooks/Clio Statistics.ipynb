# %%
import urllib2 
import simplejson
import json
import pandas as pd
import re
import vincent
import numpy as np
from pandas.io.json import json_normalize

def load_api_data(apiurl, fileID):
    jsondataurl = apiurl
    
    req = urllib2.Request(jsondataurl)
    opener = urllib2.build_opener()
    f = opener.open(req)
    dataframe = simplejson.load(f, "utf-8")
    return dataframe

def loadnames(dataframe):
    header = dataframe[1]
    names = {}
    for name in header:
        try:
            names[name] = int(header[name])
        except:
            names[name] = header[name]
    return names

def transform(dataframe, names):
    transframe = {}
    for item in dataframe:
        for code in item:
            thisyear = names[code]
            value = item[code]            
            if not value:
                value = np.nan
            
            try:
                dataset = transframe[thisyear]
            except:
                dataset = []
                
            dataset.append(value)        
            transframe[thisyear] = dataset

    return transframe

def createdata(jsonapi):
    dataframe = load_api_data(jsonapi, '')
    names = loadnames(dataframe)
    dataframe.pop(0)
    dataframe.pop(0)
    t = transform(dataframe, names)
    c = pd.DataFrame(t)
    c = c.drop('Code', axis=1)
    c = c.set_index('Continent, Region, Country')
    
    return c

# %%
jsonapi = "http://clearance.sandbox.socialhistoryservices.org/collabs/static/data/dataframe27_0.json"
data = createdata(jsonapi)
min = data[1900].min()
max = data[1900].max()
mean = data[1900].mean()
median = data[1900].median()
print median
data[1900].mean()
d = data.describe()
show = d.transpose()
show
# Out:
# 48.84
#       count       mean        std    min      25%     50%      75%    max
# 1750      1  39.880000        NaN  39.88  39.8800  39.880  39.8800  39.88
# 1800      1  33.150000        NaN  33.15  33.1500  33.150  33.1500  33.15
# 1810      2  37.350000   5.260874  33.63  35.4900  37.350  39.2100  41.07
# 1820      2  40.890000   1.343503  39.94  40.4150  40.890  41.3650  41.84
# 1830      4  39.542500   3.837042  34.23  38.7150  40.270  41.0975  43.40
# 1840      6  42.030000   5.784400  32.61  40.5325  41.740  45.1600  49.66
# 1850      7  44.122857   4.308069  38.29  41.4550  43.970  46.2000  51.29
# 1860      7  42.354286  10.202044  21.46  40.9100  45.700  48.1000  51.30
# 1870     10  41.933000   6.045290  30.20  38.7825  41.770  45.7350  52.55
# 1880     10  44.045000   5.234408  33.14  42.2775  43.950  45.4725  53.28
# 1890     10  45.963000   4.665964  38.57  44.9750  46.095  47.8875  53.03
# 1900     11  48.459091   4.621633  41.80  45.0250  48.840  51.6800  55.15
# 1910     11  53.540909   5.488939  41.97  51.4400  54.600  57.6400  59.63
# 1920     14  55.350714   6.170158  40.35  53.9775  57.250  58.8350  63.24
# 1930     15  61.358667   4.191517  51.13  59.2900  62.820  63.8500  66.88
# 1940     20  62.785000   5.830996  52.45  58.6700  64.685  67.4950  70.83
# 1950     31  69.019677   3.697886  60.90  67.0900  70.590  71.8400  73.53
# 1960    186  56.468011  12.675195  30.81  45.7850  58.070  67.4850  75.86
# 1970    189  60.734709  11.938707  34.63  50.6400  63.690  71.4200  77.31
# 1980    193  64.738394  11.132966  35.70  56.4600  68.370  74.1500  80.07
# 1990    200  67.878350  10.810168  34.61  61.1450  71.545  75.8400  82.50
# 2000    200  69.277050  11.976431   8.03  62.5225  73.390  77.9575  84.58
