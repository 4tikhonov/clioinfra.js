# %%
import json
import sys
import os
import re
import simplejson
import pandas as pd
sys.path.append(os.path.abspath(os.path.join(os.path.dirname("__file__"), '../modules')))
from config import configuration, dataverse2indicators, load_dataverse, findpid, load_metadata
from storage import data2store, readdata, readdataset, readdatasets, datasetadd, formdatasetquery
from datasets import loaddataset, loaddataset_fromurl, loadgeocoder, treemap, selectint, buildgeocoder, load_geocodes, datasetfilter, dataset_analyzer
from data2excel import create_excel_dataset
from sys import argv
from historical_data import save_historical_dataset
from random import randint
import openpyxl
from datetime import datetime
from openpyxl.cell import get_column_letter
import numpy as np

handles = []
remote = 'on'
config = configuration()
config['remote'] = 'yes'

# Geocoder
handle = config['geocoderhandle']
if remote:
    (classification, dataset, title, units) = loaddataset_fromurl(config, handle)
else:
    dataset = loaddataset(handles)

(geocoder, geolist, oecd2webmapper) = buildgeocoder(dataset, config, '')
(modern, historical) = loadgeocoder(config, dataset, 'geocoder')
coderyears = []
for i in range(1500, 2015):
    coderyears.append(i)
# Out:
# http://dpe.sandbox.socialhistoryservices.org/api/datasets?handle=Panel[%27hdl:10622/WNGZ4A]&format=csv

# %% [markdown]
# Let's load and analyze dataset

# %%
handle = "hdl:10622/WNGZ4A"
#handle = "hdl:10622/DIUBXI"
handle = "hdl:10622/UFGBH1"
handle = "hdl:10622/I0YK5M"
handle = "hdl:10622/F16UDU"
handle = "hdl:10622/CSNW0F"
handles = []
handles.append(handle)
#switch = 'historical'
switch = 'modern'

if config['remote']:
    (class1, dataset, title, units) = loaddataset_fromurl(config, handle)
else:
    dataset = loaddataset(handles)

if switch == 'modern':
    activeindex = modern.index
    coder = modern
    class1 = switch
else:
    activeindex = historical.index
    coder = historical

dataset
# Out:
# http://dpe.sandbox.socialhistoryservices.org/api/datasets?handle=Panel[%27hdl:10622/CSNW0F]&format=csv
#                1          Code  \
# Code
# in thousands   0  in thousands
# Code           1          Code
# 150            2           150
# 155            3           155
# 40             4            40
# 56             5            56
# 280            6           280
# 250            7           250
# 278            8           278
# 276            9           276
# 438           10           438
# 442           11           442
# 492           12           492
# 528           13           528
# 756           14           756
# NaN           15           NaN
# 154           16           154
# 248           17           248
# 830           18           830
# 208           19           208
# 233           20           233
# 234           21           234
# 246           22           246
# 831           23           831
# 352           24           352
# 372           25           372
# 833           26           833
# 832           27           832
# 428           28           428
# 440           29           440
# 578           30           578
# 680           31           680
# 744           32           744
# 752           33           752
# 826           34           826
# NaN           35           NaN
# 39            36            39
# 8             37             8
# 20            38            20
# 70            39            70
# 191           40           191
# 292           41           292
# 300           42           300
# 336           43           336
# 380           44           380
# NaN           45           NaN
# 470           46           470
# 499           47           499
# 620           48           620
# 674           49           674
# 688           50           688
# 891           51           891
# 705           52           705
# 890           53           890
# 724           54           724
# 807           55           807
# NaN           56           NaN
# 151           57           151
# 112           58           112
# 100           59           100
#              ...           ...
#
#                                      Continent, Region, Country   1500  \
# Code
# in thousands                                                NaN    NaN
# Code                                 Continent, Region, Country   1500
# 150                                                      Europe    NaN
# 155                                              Western Europe    NaN
# 40                                                      Austria   2000
# 56                                                      Belgium   1400
# 280                    Federal Republic of Germany (until 1990)    NaN
# 250                                                      France  15000
# 278                     German Democratic Republic (until 1990)    NaN
# 276                                                     Germany  12000
# 438                                               Liechtenstein    NaN
# 442                                                  Luxembourg    NaN
# 492                                                      Monaco    NaN
# 528                                                 Netherlands    950
# 756                                                 Switzerland    650
# NaN                                                         NaN    NaN
# 154                                             Northern Europe    NaN
# 248                                               Åland Islands    NaN
# 830                                             Channel Islands    NaN
# 208                                                     Denmark    600
# 233                                                     Estonia    NaN
# 234                                              Faeroe Islands    NaN
# 246                                                     Finland    300
# 831                                                    Guernsey    NaN
# 352                                                     Iceland    NaN
# 372                                                     Ireland    800
# 833                                                 Isle of Man    NaN
# 832                                                      Jersey    NaN
# 428                                                      Latvia    NaN
# 440                                                   Lithuania    NaN
# 578                                                      Norway    300
# 680                                                        Sark    NaN
# 744                              Svalbard and Jan Mayen Islands    NaN
# 752                                                      Sweden    550
# 826           United Kingdom of Great Britain and Northern I...   3942
# NaN                                                         NaN    NaN
# 39                                              Southern Europe    NaN
# 8                                                       Albania    200
# 20                                                      Andorra    NaN
# 70                                       Bosnia and Herzegovina    NaN
# 191                                                     Croatia    NaN
# 292                                                   Gibraltar    NaN
# 300                                                      Greece   1000
# 336                                                    Holy See    NaN
# 380                                                       Italy  10500
# NaN                                                      Kosovo    NaN
# 470                                                       Malta    NaN
# 499                                                  Montenegro    NaN
# 620                                                    Portugal   1000
# 674                                                  San Marino    NaN
# 688                                                      Serbia    NaN
# 891                          Serbia and Montenegro (until 2006)    NaN
# 705                                                    Slovenia    NaN
# 890           Socialist Federal Republic of Yugoslavia (unti...   2250
# 724                                                       Spain   6800
# 807                   The former Yugoslav Republic of Macedonia    NaN
# NaN                                                         NaN    NaN
# 151                                              Eastern Europe    NaN
# 112                                                     Belarus    NaN
# 100                                                    Bulgaria    800
#                                                             ...    ...
#
#                 1550     1600     1650     1700     1750      1800   1810  \
# Code
# in thousands     NaN      NaN      NaN      NaN      NaN       NaN    NaN
# Code          1550.0   1600.0   1650.0   1700.0   1750.0    1800.0   1810
# 150              NaN      NaN      NaN      NaN      NaN       NaN    NaN
# 155              NaN      NaN      NaN      NaN      NaN       NaN    NaN
# 40               NaN   2500.0   2250.0   2500.0   2750.0    3000.0    NaN
# 56               NaN   1600.0   1500.0   2000.0   2250.0    3250.0    NaN
# 280              NaN      NaN      NaN      NaN      NaN   14747.0    NaN
# 250              NaN  18500.0  21000.0  21471.0  24000.0   29000.0    NaN
# 278              NaN      NaN      NaN      NaN      NaN  5773.904    NaN
# 276              NaN  16000.0  11000.0  15000.0  15000.0   18000.0    NaN
# 438              NaN      NaN      NaN      NaN      NaN     5.802    NaN
# 442              NaN      NaN      NaN      NaN      NaN    127.03    NaN
# 492              NaN      NaN      NaN      NaN      NaN     7.789    NaN
# 528              NaN   1500.0   2000.0   1900.0   2000.0    2000.0   2047
# 756              NaN   1000.0   1000.0   1200.0   1500.0    1750.0    NaN
# NaN              NaN      NaN      NaN      NaN      NaN       NaN    NaN
# 154              NaN      NaN      NaN      NaN      NaN       NaN    NaN
# 248              NaN      NaN      NaN    2.919      NaN       NaN    NaN
# 830              NaN      NaN      NaN      NaN      NaN    43.908    NaN
# 208              NaN    650.0      NaN    700.0      NaN    1000.0    NaN
# 233              NaN      NaN      NaN      NaN      NaN   334.136    NaN
# 234              NaN      NaN      NaN      NaN      NaN    13.537    NaN
# 246              NaN    400.0      NaN    400.0      NaN     800.0    NaN
# 831              NaN      NaN      NaN      NaN      NaN    19.488    NaN
# 352              NaN      NaN      NaN      NaN     46.0    61.428    NaN
# 372              NaN   1000.0   1750.0   1925.0   3000.0    5250.0    NaN
# 833              NaN      NaN      NaN      NaN      NaN    23.533    NaN
# 832              NaN      NaN      NaN      NaN      NaN     24.42    NaN
# 428              NaN      NaN      NaN      NaN      NaN   590.588    NaN
# 440              NaN      NaN      NaN      NaN      NaN   778.655    NaN
# 578              NaN    400.0      NaN    500.0    724.0     900.0    885
# 680              NaN      NaN      NaN      NaN      NaN       NaN    NaN
# 744              NaN      NaN      NaN      NaN      NaN       NaN    NaN
# 752              NaN    760.0      NaN   1260.0   1781.0    2500.0   2396
# 826              NaN   6170.0   5800.0   8565.0   7250.0   10750.0  11970
# NaN              NaN      NaN      NaN      NaN      NaN       NaN    NaN
# 39               NaN      NaN      NaN      NaN      NaN       NaN    NaN
# 8                NaN    200.0      NaN    300.0      NaN     400.0    NaN
# 20               NaN      NaN      NaN      NaN      NaN     2.654    NaN
# 70               NaN      NaN      NaN      NaN      NaN   851.806    NaN
# 191              NaN      NaN      NaN      NaN      NaN  1227.886    NaN
# 292              NaN      NaN      NaN      NaN      NaN     9.873    NaN
# 300              NaN   1500.0      NaN   1500.0      NaN    2250.0    NaN
# 336              NaN      NaN      NaN      NaN      NaN       NaN    NaN
# 380              NaN  13100.0  11000.0  13300.0  15000.0   19000.0    NaN
# NaN              NaN      NaN      NaN      NaN      NaN   383.778    NaN
# 470              NaN      NaN      NaN      NaN      NaN   134.072    NaN
# 499              NaN      NaN      NaN      NaN      NaN   126.582    NaN
# 620              NaN   1100.0   1750.0   2000.0   2250.0    2750.0    NaN
# 674              NaN      NaN      NaN      NaN      NaN     5.492    NaN
# 688              NaN      NaN      NaN      NaN      NaN  2147.197    NaN
# 891              NaN      NaN      NaN      NaN      NaN   2273.78    NaN
# 705              NaN      NaN      NaN      NaN      NaN   469.664    NaN
# 890              NaN   2750.0      NaN   2750.0      NaN    4750.0    NaN
# 724              NaN   8240.0   7500.0   8770.0   9500.0   11500.0    NaN
# 807              NaN      NaN      NaN      NaN      NaN   391.865    NaN
# NaN              NaN      NaN      NaN      NaN      NaN       NaN    NaN
# 151              NaN      NaN      NaN      NaN      NaN       NaN    NaN
# 112              NaN      NaN      NaN      NaN      NaN  2355.081    NaN
# 100              NaN   1250.0      NaN   1250.0      NaN    2250.0    NaN
#                  ...      ...      ...      ...      ...       ...    ...
#
#                   1820     1830     1840     1850     1860      1870     1880  \
# Code
# in thousands       NaN      NaN      NaN      NaN      NaN       NaN      NaN
# Code            1820.0   1830.0   1840.0   1850.0   1860.0    1870.0   1880.0
# 150                NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 155                NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 40              3369.0   3538.0   3716.0   3950.0   4235.0    4520.0   4941.0
# 56              3434.0   3750.0   4080.0   4449.0   4740.0    5096.0   5541.0
# 280            14747.0      NaN      NaN      NaN      NaN   23055.0      NaN
# 250            31250.0  33300.0  34900.0  36350.0  37300.0   38440.0  39045.0
# 278           5773.904      NaN      NaN      NaN      NaN  9095.203      NaN
# 276            24905.0  28045.0  31126.0  33746.0  36049.0   39231.0  43500.0
# 438              5.802      NaN      NaN      NaN      NaN       NaN      NaN
# 442             127.03    170.0    180.0    193.0    203.0     198.0    210.0
# 492              7.789      NaN      NaN      NaN      NaN       NaN      NaN
# 528             2333.0   2633.0   2886.0   3098.0   3318.0    3610.0   4043.0
# 756             1986.0   2100.0   2220.0   2379.0   2510.0    2655.0   2839.0
# NaN                NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 154                NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 248              8.532      NaN      NaN      NaN      NaN       NaN      NaN
# 830             43.908      NaN      NaN      NaN      NaN       NaN      NaN
# 208             1155.0   1273.0   1357.0   1499.0   1696.0    1888.0   2081.0
# 233            334.136      NaN      NaN      NaN      NaN       NaN      NaN
# 234             13.537      NaN      NaN      NaN      NaN       NaN      NaN
# 246             1169.0   1364.0   1441.0   1628.0   1738.0    1754.0   2047.0
# 831             19.488      NaN      NaN      NaN      NaN       NaN      NaN
# 352             61.428      NaN     57.0     59.0     67.0      70.0     72.0
# 372             7101.0   7827.0   8349.0   6878.0   5821.0    5419.0   5203.0
# 833             23.533      NaN      NaN      NaN      NaN       NaN      NaN
# 832              24.42      NaN      NaN      NaN      NaN       NaN      NaN
# 428            590.588      NaN      NaN      NaN      NaN       NaN      NaN
# 440            778.655      NaN      NaN      NaN      NaN       NaN      NaN
# 578              970.0   1124.0   1241.0   1392.0   1596.0    1735.0   1919.0
# 680                NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 744                NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 752             2573.0   2876.0   3123.0   3462.0   3824.0    4164.0   4572.0
# 826            21239.0  24139.0  26745.0  27181.0  28888.0   31400.0  34623.0
# NaN                NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 39                 NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 8                437.0      NaN      NaN    500.0      NaN     603.0      NaN
# 20               2.654      NaN      NaN      NaN      NaN       NaN      NaN
# 70             851.806      NaN      NaN      NaN      NaN    1158.0   1360.0
# 191           1227.886      NaN      NaN      NaN      NaN       NaN      NaN
# 292              9.873      NaN      NaN      NaN      NaN       NaN      NaN
# 300             2312.0   2534.0   2777.0   3044.0   3336.0    3657.0   4049.0
# 336                NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 380            20176.0  21513.0  22939.0  24460.0  26081.0   27888.0  29534.0
# NaN            383.778      NaN      NaN      NaN      NaN       NaN      NaN
# 470            134.072      NaN      NaN      NaN      NaN       NaN      NaN
# 499            126.582      NaN      NaN      NaN      NaN       NaN      NaN
# 620             3297.0   3491.0   3704.0   3816.0   4000.0    4327.0   4610.0
# 674              5.492      NaN      NaN      NaN      NaN       NaN      NaN
# 688           2147.197      NaN      NaN      NaN      NaN       NaN   1902.0
# 891            2273.78      NaN      NaN      NaN      NaN       NaN      NaN
# 705            469.664      NaN      NaN      NaN      NaN       NaN      NaN
# 890             5215.0      NaN      NaN   6000.0      NaN    8252.0      NaN
# 724            12203.0  13041.0  13937.0  14894.0  15642.0   16201.0  16859.0
# 807            391.865      NaN      NaN      NaN      NaN       NaN      NaN
# NaN                NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 151                NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 112           2355.081      NaN      NaN      NaN      NaN       NaN      NaN
# 100             2187.0      NaN      NaN   2500.0      NaN    2586.0      NaN
#                    ...      ...      ...      ...      ...       ...      ...
#
#                  1890     1900
# Code
# in thousands      NaN      NaN ...
# Code           1890.0   1900.0 ...
# 150               NaN      NaN ...
# 155               NaN      NaN ...
# 40             5394.0   5973.0 ...
# 56             6096.0   6719.0 ...
# 280               NaN      NaN ...
# 250           40014.0  40598.0 ...
# 278               NaN      NaN ...
# 276           47607.0  54388.0 ...
# 438               NaN      NaN ...
# 442             211.0    236.0 ...
# 492               NaN      NaN ...
# 528            4535.0   5142.0 ...
# 756            2951.0   3300.0 ...
# NaN               NaN      NaN ...
# 154               NaN      NaN ...
# 248               NaN      NaN ...
# 830               NaN      NaN ...
# 208            2294.0   2561.0 ...
# 233               NaN      NaN ...
# 234               NaN      NaN ...
# 246            2364.0   2646.0 ...
# 831               NaN      NaN ...
# 352              71.0     78.0 ...
# 372            4718.0   4469.0 ...
# 833               NaN      NaN ...
# 832               NaN      NaN ...
# 428               NaN      NaN ...
# 440               NaN      NaN ...
# 578            1997.0   2230.0 ...
# 680               NaN      NaN ...
# 744               NaN      NaN ...
# 752            4780.0   5117.0 ...
# 826           37485.0  41155.0 ...
# NaN               NaN      NaN ...
# 39                NaN      NaN ...
# 8               726.0    800.0 ...
# 20                NaN      NaN ...
# 70             1568.0      NaN ...
# 191               NaN      NaN ...
# 292               NaN      NaN ...
# 300            4482.0   4962.0 ...
# 336               NaN      NaN ...
# 380           31702.0  33672.0 ...
# NaN               NaN      NaN ...
# 470               NaN      NaN ...
# 499               NaN      NaN ...
# 620            5028.0   5404.0 ...
# 674               NaN      NaN ...
# 688            2162.0   2494.0 ...
# 891               NaN      NaN ...
# 705               NaN      NaN ...
# 890            9690.0  11174.0 ...
# 724           17757.0  18566.0 ...
# 807               NaN      NaN ...
# NaN               NaN      NaN ...
# 151               NaN      NaN ...
# 112               NaN      NaN ...
# 100            3445.0   4000.0 ...
#                   ...      ...
#
# [308 rows x 30 columns]

# %%
(moderndata, historicaldata) = loadgeocoder(config, dataset, '')
if switch == 'modern':
    maindata = moderndata
else:
    # Do conversion to webmapper system
    if not historicaldata:
        maindata = moderndata
        webmapperindex = []
        for code in maindata.index:
            try:
                webmappercode = oecd2webmapper[int(code)]
            except:
                webmappercode = -1
            webmapperindex.append(webmappercode)
        maindata.index = webmapperindex
        maindata = maindata[maindata.index > 0]
    else:
        maindata = historicaldata
    
(cfilter, notint) = selectint(maindata.columns)
    
codes = selectint(maindata.index)
geo = load_geocodes(config, switch, codes, maindata, geolist)
for colname in notint:
    maindata = maindata.drop(colname, axis=1)
print title
#maindata.ix[-1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-ebd8032a603d> in <module>()
# ----> 1 (moderndata, historicaldata) = loadgeocoder(config, dataset, '')
#       2 if switch == 'modern':
#       3     maindata = moderndata
#       4 else:
#       5     # Do conversion to webmapper system
#
# /home/tikhonov/dev/clioinfra.js/modules/datasets.pyc in loadgeocoder(config, dataset, action)
#      90         geocoder = dataset.iloc[:, 1:12]
#      91     else:
# ---> 92         geocoder = geocoder.ix[3:]
#      93     if action == 'test':
#      94         return (geocoder, geocoder)
#
# AttributeError: 'str' object has no attribute 'ix'

# %% [markdown]
# Dataset filters

# %%
# Use case 1
datafilter = {}
datafilter['startyear'] = '1950'
datafilter['endyear'] = '2010'
datafilter['ctrlist'] = ''
#datafilter['ctrlist'] = '528,14,18,67'
datafilter['ctrlist'] = '528'
datafilter['ctrlist'] = '1523'
if datafilter['startyear']:
    coderyears = []
    for i in range(int(datafilter['startyear']), int(datafilter['endyear'])):
        coderyears.append(i)
(datasubset, ctrlist) = datasetfilter(maindata, datafilter)

# %%
fullpath = "subdata_set.xlsx"
metadata = {}
metadata['title'] = 'testtitle'
metadata['units'] = 'testunits'
if title:
    metadata['title'] = title
if units:
    metadata['units'] = units

(yearscolumns, notyears) = selectint(maindata.columns)
(countryinfo, notcountry) = selectint(maindata.index)
            
a = datetime.now()    
(finalsubset, icoder, isyear, ctrfilter, nodata) = dataset_analyzer(datasubset, coder, yearscolumns)
if datafilter['ctrlist']:
    tmpcoder = icoder.ix[ctrlist]
    icoder = pd.DataFrame(tmpcoder)
datafile = create_excel_dataset(fullpath, icoder, metadata, icoder.columns, coderyears, finalsubset, isyear, ctrfilter)
b = datetime.now()
d = b - a
print "Time: " + str(d.seconds) + " seconds"
print datafile
#yearscolumns
#xset.ix[67][1831]
#icoder = icoder.ix[68]
#finalsubset.ix[528][1970]
finalsubset
